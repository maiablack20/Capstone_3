# %% [markdown]
# # Capstone_2
# ## Myleah Richardson

# %% [markdown]
# ### project Descripiton: this notebook is to analyzes EmporiUm sales data for two of there territories
# ### territory 1 - the west region in the state of colorado as Jim heck as the manager
# ### territory 2 - the east region in the state of New York as See Ellefson as the manager

# %%
# importing tools i  will need for analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# i notieced when reviewing the table that they were getting cut off, to stop that i added 
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:,.2f}'.format)

# creating a code to load storesales files
sales = pd.read_excel("StoreSales (1).csv.xlsx")

# seeing what are the column names, number of NaN values and data types
sales.info()

# seeing what comes up 
sales.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 335129 entries, 0 to 335128
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction Date  335129 non-null  datetime64[us]
#  1   Store ID          335129 non-null  int64
#  2   RewardsID         34943 non-null   float64
#  3   Prod Num          335129 non-null  str
#  4   Sale Amount       335129 non-null  float64
# dtypes: datetime64[us](1), float64(2), int64(1), str(1)
# memory usage: 12.8 MB
#   Transaction Date  Store ID  RewardsID  Prod Num  Sale Amount
# 0       2022-01-01       702        NaN  105349-M         8.00
# 1       2022-01-01       704        NaN  105350-T       144.00
# 2       2022-01-01       705        NaN  105351-M        44.00
# 3       2022-01-01       705        NaN  105352-M        47.61
# 4       2022-01-01       705        NaN  105353-A        20.36

# %%
# looking at my data it has NaN becuase there is no value for RewardsID, using this fuction will allow me to see how many values are missing in my data
sales.isna().sum()
# Out:
# Transaction Date         0
# Store ID                 0
# RewardsID           300186
# Prod Num                 0
# Sale Amount              0
# dtype: int64

# %%
#replacing all NaN values with ""
sales = sales.fillna("")

# %%
# now just seeing if my function relpace the NaN value with ""or blank
sales.info()
print("\n-----------Initial Rows:----------\n", sales.head())
print("\nstore_sales Shape:", sales.shape)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 335129 entries, 0 to 335128
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction Date  335129 non-null  datetime64[us]
#  1   Store ID          335129 non-null  int64
#  2   RewardsID         335129 non-null  object
#  3   Prod Num          335129 non-null  str
#  4   Sale Amount       335129 non-null  float64
# dtypes: datetime64[us](1), float64(1), int64(1), object(1), str(1)
# memory usage: 12.8+ MB
#
# -----------Initial Rows:----------
#    Transaction Date  Store ID RewardsID  Prod Num  Sale Amount
# 0       2022-01-01       702            105349-M         8.00
# 1       2022-01-01       704            105350-T       144.00
# 2       2022-01-01       705            105351-M        44.00
# 3       2022-01-01       705            105352-M        47.61
# 4       2022-01-01       705            105353-A        20.36
#
# ...

# %%
#repeating the same for each csv file

#creating a code to read StoreDetail file
details = pd.read_excel("StoreDetail (1).csv.xlsx")

# DataFrame Inspection Methods & Attributes
details.info()
print("\n-----------Initial Rows:----------\n", details.head())
print("\nstore_details Shape:", details.shape)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Store Location     111 non-null    str
#  1   State              111 non-null    str
#  2   Store ID           111 non-null    int64
#  3   Territory Manager  111 non-null    str
#  4   Region             111 non-null    str
#  5   Region Director    111 non-null    str
# dtypes: int64(1), str(5)
# memory usage: 5.3 KB
#
# -----------Initial Rows:----------
#    Store Location     State  Store ID Territory Manager Region  Region Director
# 0         Aurora  Colorado       701          Jim Heck   West  Cassie Chambers
# 1       Berthoud  Colorado       702          Jim Heck   West  Cassie Chambers
# 2        Boulder  Colorado       703          Jim Heck   West  Cassie Chambers
# 3    Castle Rock  Colorado       704          Jim Heck   West  Cassie Chambers
# ...

# %%
#creating a code to read Products file
products = pd.read_excel("Products (1).csv.xlsx")

#  DataFrame Inspection Methods & Attributes
products.info()
print("\n-----------Initial Rows:----------\n", products.head())
print("\nproducts Shape:", products.shape)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 669 entries, 0 to 668
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Prod Num       669 non-null    str
#  1   Product        669 non-null    object
#  2   CategoryID     669 non-null    int64
#  3   SubcategoryID  669 non-null    str
# dtypes: int64(1), object(1), str(2)
# memory usage: 21.0+ KB
#
# -----------Initial Rows:----------
#      Prod Num                        Product  CategoryID SubcategoryID
# 0  105248-IT               TCL NXTPAPER 10s         120       120-tab
# 1  105249-IT  Dell Latitude 7320 Detachable         120       120-tab
# 2  105250-IT                     Realme Pad         120       120-tab
# 3  105251-IT             Lenovo Tab P12 Pro         120       120-tab
# 4  105252-IT        Microsoft Surface Pro 9         120       120-tab
#
# products Shape: (669, 4)

# %%
#creating a code to read ProudctsCategories file

productC = pd.read_excel("ProductCategories (1).csv.xlsx")

# DataFrame Inspection Methods & Attributes
productC.info()
print("\n-----------Initial Rows:----------\n", productC.head())
print("\nproduct_categories Shape:", productC.shape)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CategoryID     52 non-null     int64
#  1   Category       52 non-null     str
#  2   SubcategoryID  52 non-null     str
#  3   Subcategory    52 non-null     str
# dtypes: int64(1), str(3)
# memory usage: 1.8 KB
#
# -----------Initial Rows:----------
#     CategoryID                  Category SubcategoryID           Subcategory
# 0         120  Technology & Accessories       120-tab               Tablets
# 1         120  Technology & Accessories       120-cal           Calculators
# 2         120  Technology & Accessories       120-sof     Software Download
# 3         120  Technology & Accessories       120-hea            Headphones
# 4         120  Technology & Accessories       120-ext  External Accessories
#
# product_categories Shape: (52, 4)

# %%
#creating a code to read customerlist file
Clist = pd.read_excel("customer_list (1).csv.xlsx")

# because i saved my files as execel i did not have to use ( sep '|') to separate the cloumns
# had split my columns because it had to many columns
Clist = Clist.iloc[:,0].str.split('|', expand=True)
Clist.columns = [
    'cust_id',
    'date',
    'time',
    'name',
    'email',
    'phone',
    'sms_opt_out'
]
# DataFrame Inspection Methods & Attributes
Clist.info()
print("\n-----------Initial Rows:----------\n", Clist.head())
print("\ncustomer_list Shape:", Clist.shape)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cust_id      521 non-null    str
#  1   date         521 non-null    str
#  2   time         521 non-null    str
#  3   name         521 non-null    str
#  4   email        521 non-null    str
#  5   phone        520 non-null    str
#  6   sms_opt_out  520 non-null    str
# dtypes: str(7)
# memory usage: 28.6 KB
#
# -----------Initial Rows:----------
#    cust_id        date      time           name  \
# 0       1  2023-03-15  08:45:12         Rachel
# 1       2  2023-05-22  12:30:45      R. Geller
# 2       3  2023-07-09  18:15:27  Monica Geller
# 3       4  2023-09-01  21:05:33  Chandler Bing
# 4       5  2023-11-18  14:22:10           Joey
#
#                             email         phone sms_opt_out
# 0       rachel@centralperk.coffee  212-555-1001           N
# ...

# %% [markdown]
# ## Core Marketing Analysis

# %%
# filtering store list for only 2 territories with managers assigned to territore
# 1- New york
# 2 - Colorado 

# Create West territory DataFrame
west = details[details['Region'] == 'West']

# Create East territory DataFrame
east = details[details['Region'] == 'East']

# %%
# creating a filter for each territory west and east i am signed to
#East:
details[details["State"]=="New York"]
# Out:
#    Store Location     State  Store ID Territory Manager Region Region Director
# 86         Albany  New York       840      See Ellefson   East      Ana Jilani
# 87        Buffalo  New York       841      See Ellefson   East      Ana Jilani
# 88         Elmira  New York       842      See Ellefson   East      Ana Jilani
# 89         Ithaca  New York       843      See Ellefson   East      Ana Jilani
# 90         Oswego  New York       844      See Ellefson   East      Ana Jilani
# 91    Plattsburgh  New York       845      See Ellefson   East      Ana Jilani
# 92    Poestenkill  New York       846      See Ellefson   East      Ana Jilani
# 93      Rochester  New York       847      See Ellefson   East      Ana Jilani
# 94       Syracuse  New York       848      See Ellefson   East      Ana Jilani
# 95       Brooklyn  New York       849      See Ellefson   East      Ana Jilani
# 96       New York  New York       850      See Ellefson   East      Ana Jilani
# ...

# %%
# West:
details[details["State"]== "Colorado"]
# Out:
#     Store Location     State  Store ID Territory Manager Region  \
# 0           Aurora  Colorado       701          Jim Heck   West
# 1         Berthoud  Colorado       702          Jim Heck   West
# 2          Boulder  Colorado       703          Jim Heck   West
# 3      Castle Rock  Colorado       704          Jim Heck   West
# 4           Denver  Colorado       705          Jim Heck   West
# 5        Englewood  Colorado       706          Jim Heck   West
# 6     Fort Collins  Colorado       707          Jim Heck   West
# 7   Grand Junction  Colorado       708          Jim Heck   West
# 8          Greeley  Colorado       709          Jim Heck   West
# 9        Lafayette  Colorado       710          Jim Heck   West
# 10       Littleton  Colorado       711          Jim Heck   West
# 11        Loveland  Colorado       712          Jim Heck   West
# 12        Milliken  Colorado       713          Jim Heck   West
# 13      New Castle  Colorado       714          Jim Heck   West
# ...

# %% [markdown]
# ## New York is managed by See Ellefson(East Region) and has 12 stores
# ## colorado is mangaged by Jim Heck (West Region) and has 18 stores

# %%
# Q2 What is monthly total revenue for in-store sales in each of the two sales territories, over the full period covered by the data?

# %% [markdown]
# ## Monthly Revenue

# %%
colorado = my_sales[my_sales['State'] == 'Colorado']

newyork = my_sales[my_sales['State'] == 'New York']

# %%
# Merge storesales(sales) and storedetail(detail) 
# to get the territory and state information 
stateS = sales.merge(detail[['Store ID', 'State']], on='Store ID')


# filter it for new york and colorado
my_sales = stateS[stateS['State'].isin (['Colorado', 'New York'])]

# Convert Transaction Date to datetime format
stateS['Transaction Date'] = pd.to_datetime(stateS['Transaction Date'])

# coverting transaction date into MONTHS only,using .dt for date/time functions, .to_period('M')
# coverting the dates into monthly periods, and monthlyR gets stored
monthlyR = stateS['Transaction Date'].dt.to_period('M')

# storeing only YEAR and MONTH from each transaction date
my_sales['YearMonth'] = my_sales['Transaction Date']. dt.to_period('M')

# Group by the monthly period to get territory totals
Co_monthly_revenue = colorado.groupby('YearMonth')['Sale Amount'].sum()
NY_monthly_revenue = newyork.groupby('YearMonth')['Sale Amount'].sum()

print("--- Colorado Monthly Total Revenue ---")
print(Co_monthly_revenue.to_frame('Total Revenue'))

print("\n--- NewYork Monthly Total Revenue ---")
print(NY_monthly_revenue.to_frame('Total Revenue'))
# Out:
# --- Colorado Monthly Total Revenue ---
#            Total Revenue
# YearMonth
# 2022-01        77,950.98
# 2022-02        80,315.69
# 2022-03        82,516.36
# 2022-04        89,350.31
# 2022-05        94,892.89
# 2022-06        86,847.70
# 2022-07        94,048.49
# 2022-08        87,058.36
# 2022-09        84,206.09
# 2022-10        78,706.96
# 2022-11        76,920.06
# 2022-12        78,541.63
# 2023-01       127,097.69
# 2023-02       118,165.45
# 2023-03       113,336.10
# 2023-04       131,835.33
# 2023-05       126,201.30
# 2023-06       110,745.70
# 2023-07       137,070.84
# 2023-08       132,936.24
# 2023-09       137,022.60
# 2023-10       118,913.30
# 2023-11       122,127.52
# 2023-12       112,438.65
# 2024-01       130,507.83
# 2024-02       104,570.81
# 2024-03       133,808.20
# 2024-04       124,228.43
# 2024-05       116,437.33
# 2024-06       131,379.21
# 2024-07       132,936.24
# 2024-08       139,385.22
# 2024-09       116,550.68
# 2024-10       124,204.24
# ...

# %% [markdown]
# ## store sales ranking

# %%
# Q3 How would you rank the sales performance of each store in each sales territory? Which are the top-performing stores?

# %%
# total revenue per store and sort from highest to lowest 
Ny_ranking = newyork.groupby(['Store ID', 'State'])['Sale Amount'].sum().sort_values(ascending=False)
C_ranking = colorado.groupby(['Store ID', 'State'])['Sale Amount'].sum().sort_values(ascending=False)

print("--- New York sales ranking ---")
print(Ny_ranking.to_frame('Total Revenue'))

print("\n--- Colorado Store sales ranking ---")
print(C_ranking.to_frame('Total Revenue'))
# Out:
# --- New York sales ranking ---
#                    Total Revenue
# Store ID State
# 850      New York     621,565.02
# 847      New York     607,148.21
# 846      New York     334,175.88
# 841      New York     314,979.99
# 842      New York     313,971.65
# 843      New York     313,920.05
# 845      New York     311,520.52
# 840      New York     310,389.02
# 848      New York     306,998.14
# 849      New York     304,732.76
# 844      New York     302,862.71
# 851      New York     288,553.14
#
# --- Colorado Store sales ranking ---
#                    Total Revenue
# Store ID State
# 705      Colorado     917,471.53
# 709      Colorado     640,368.11
# 706      Colorado     344,647.48
# 710      Colorado     337,169.61
# 703      Colorado     321,197.88
# 716      Colorado     319,776.13
# 701      Colorado     317,198.67
# 708      Colorado     306,834.49
# 707      Colorado     302,660.34
# 704      Colorado     299,122.02
# 714      Colorado     298,504.41
# ...

# %% [markdown]
# ## side note: i had to use 'State' instead of 'Store Location' because python could not find 'Store location'in my data
# ## using the ID numbers to see which location store has the highest and lowest

# %% [markdown]
# ### finding that store 850 New York, New York with 621,565.02 as the highest performace and 847 Rochester, New York 607,148.21. Store 851 in Queens	New York is the lowest with 288,533.14

# %% [markdown]
# ### while in Colorado the highest performing store is 705 Denver,Colorado with 917,471.53, second up is store 709 Greeley,Colorado with 640,368.11
# ### also finding that store 715 Parker,Colorado is the lowest with 279,268.94

# %% [markdown]
# # Top customers

# %%
# python is having trouble identifying 'cust_id' using this will show me what are the names in the columns
print(Clist.columns.tolist())
# Out:
# ['cust_id', 'date', 'time', 'name', 'email', 'phone', 'sms_opt_out']

# %%
# using this to remove any gaps before and after the column names
Clist.columns = Clist.columns.str.strip()

# %%
# Convert both columns to text
my_sales['RewardsID'] = my_sales['RewardsID'].astype(str)

Clist['cust_id'] = Clist['cust_id'].astype(str)

# Remove extra spaces
my_sales['RewardsID'] = my_sales['RewardsID'].str.strip()

Clist['cust_id'] = Clist['cust_id'].str.strip()

# Remove .0 if present
my_sales['RewardsID'] = my_sales['RewardsID'].str.replace('.0', '', regex=False)

Clist['cust_id'] = Clist['cust_id'].str.replace('.0', '', regex=False)

# %%
# checking the merge

print(topC.shape)

print(topC.head())
# Out:
# (8113, 14)
#   Transaction Date  Store ID RewardsID  Prod Num  Sale Amount     State  \
# 0       2022-01-01       710       357  105360-T       188.20  Colorado
# 1       2022-01-01       712       296  105362-B        17.70  Colorado
# 2       2022-01-01       714       512  105365-T       221.48  Colorado
# 3       2022-01-01       714       171  105351-M        44.00  Colorado
# 4       2022-01-01       843        47  105349-M         8.00  New York
#
#   YearMonth cust_id        date      time            name  \
# 0   2022-01     357  2024-01-14  10:45:35    Bobby Briggs
# 1   2022-01     296  2023-02-08  09:10:25  Benjamin Sisko
# 2   2022-01     512  2023-02-10  08:25:15   Phineas Flynn
# 3   2022-01     171  2023-09-23  12:25:40    Clark County
# 4   2022-01      47  2024-04-01  15:05:45      Stanley H.
#
#                        email         phone sms_opt_out
# 0         bobby@twinpeaks.wa  206-555-1606           N
# 1        sisko@ds9.starfleet  247-555-2301           N
# ...

# %%
# Merge
topC = my_sales.merge(
    Clist,
    left_on='RewardsID',
    right_on='cust_id',
    how='inner'
)

# %%
# Q4 Comparing the customer ID from the customer list data with the rewards ID from the sales data, who were the top customers in each sales territory?

# Group by state and customer
top_customers = topC.groupby(
    ['State', 'cust_id', 'name']
)['Sale Amount'].sum().reset_index()

# Sort highest spenders first
top_customers = top_customers.sort_values(
    by=['State', 'Sale Amount'],
    ascending= [True, False])

print("--- Top 5 Customers: New York ---")
print(top_customers[top_customers['State'] == 'New York'].head(5).to_string(index=False))

print("\n--- Top 5 Customers: Colorado ---")
print(top_customers[top_customers['State'] == 'Colorado'].head(5).to_string(index=False))
# Out:
# --- Top 5 Customers: New York ---
#    State cust_id          name  Sale Amount
# New York     300 Julian Bashir     6,039.32
# New York     129  Jason Morgan     3,918.72
# New York     188  Mellie Grant     3,805.61
# New York     483   Peggy Olson     3,504.20
# New York     199         Gonzo     3,441.19
#
# --- Top 5 Customers: Colorado ---
#    State cust_id           name  Sale Amount
# Colorado     245 Gloria Mendoza     7,855.66
# Colorado     375     C.J. Cregg     5,006.57
# Colorado     380  Abbey Bartlet     4,605.19
# Colorado     242  Lorna Morello     4,381.15
# Colorado     279   Adrian Veidt     4,365.77

# %% [markdown]
# ### In new york the top customer is Julian Bashir spending 6,039.32
# ### In colorado Gloria Mendoza is the top customer spending 7,855.66
# ### Between my two territories my data shows that Colorado has the highest customer activiy

# %% [markdown]
# # Transactions and revenue by month and product category

# %%
# Q5 What is the number of transactions per month by product category in each assigned territory?
#What is total sales revenue per month by category? What might this tell you about the most popular products, and where could there be opportunity for growth?

# %%
print(products.columns)
# Out:
# Index(['Prod Num', 'Product', 'CategoryID', 'SubcategoryID'], dtype='str')

# %%
my_sales.columns = my_sales.columns.str.strip()

products.columns = products.columns.str.strip()

productC.columns = productC.columns.str.strip()

# %%
sales_products = my_sales.merge(
    products,
    on='Prod Num',
    how='left', 
)
print(sales_products.shape)

print(sales_products.head())
# Out:
# (77537, 10)
#   Transaction Date  Store ID RewardsID  Prod Num  Sale Amount     State  \
# 0       2022-01-01       702            105349-M         8.00  Colorado
# 1       2022-01-01       704            105350-T       144.00  Colorado
# 2       2022-01-01       705            105351-M        44.00  Colorado
# 3       2022-01-01       705            105352-M        47.61  Colorado
# 4       2022-01-01       705            105353-A        20.36  Colorado
#
#   YearMonth                                      Product  CategoryID  \
# 0   2022-01             LTCA Year Up Gel Pen (Pack of 2)         130
# 1   2022-01                            Corporate Finance         100
# 2   2022-01  LTCA Year Up Classic Cotton T-Shirt (White)         130
# 3   2022-01          LTCA Year Up Power Bank (10,000mAh)         130
# 4   2022-01           Newsprint Paper Pad (18x24 inches)         115
#
#   SubcategoryID
# 0       130-off
# 1       100-bus
# 2       130-clo
# 3       130-tec
# ...

# %%
# Merge sales with product info
sales_products = my_sales.merge(
    products,
    left_on='Prod Num',
    right_on='Prod Num',
    how='left', 
)

# Merge with Product category on CategoryID
sales_products = sales_products.merge(
    productC,
    on ='CategoryID',
    how= 'left'

)

# Step 3: Group by State, YearMonth and Category
category_summary = sales_products.groupby(['State', 'YearMonth', 'Category']).agg(
    Transactions=('Sale Amount', 'count'),
    Total_Revenue=('Sale Amount', 'sum')
).reset_index()

# Step 4: Show total transactions and revenue by category across full period
category_totals = sales_products.groupby(['State', 'Category']).agg(
    Transactions=('Sale Amount', 'count'),
    Total_Revenue=('Sale Amount', 'sum')
).reset_index()
ategory_totals = category_totals.sort_values(['State', 'Total_Revenue'], ascending=[True, False])

# filer by territory
ny_category = monthly_category[
    monthly_category['State'] == 'New York'
]

print(ny_category.head())

co_category = monthly_category[
    monthly_category['State'] == 'Colorado'
]

print(co_category.head())

print("--- New York---")
print(category_totals[category_totals['State'] == 'New York'].to_string(index=False))

print("\n--- Colorado ---")
print(category_totals[category_totals['State'] == 'Colorado'].to_string(index=False))
# Out:
#         State YearMonth  CategoryID  Transactions  Total_Revenue
# 288  New York   2022-01         100           858     152,002.95
# 289  New York   2022-01         110           814       8,260.67
# 290  New York   2022-01         115           561      12,440.89
# 291  New York   2022-01         120           511     279,678.00
# 292  New York   2022-01         125            96       3,107.88
#       State YearMonth  CategoryID  Transactions  Total_Revenue
# 0  Colorado   2022-01         100          1166     206,352.41
# 1  Colorado   2022-01         110          1232      13,526.26
# 2  Colorado   2022-01         115           913      25,118.72
# 3  Colorado   2022-01         120           882     357,604.17
# 4  Colorado   2022-01         125           172       3,839.12
# --- New York---
#    State                 Category  Transactions  Total_Revenue
# New York  Apparel and Merchandise         49032   1,585,641.12
# ...

# %% [markdown]
# ## technology & Accessories has the higest revenue for both colorado and new york even though this product does not have the highest transaction count

# %% [markdown]
# ## Books for both region are the lowest in revenue and transactions

# %% [markdown]
# # Recommendation for Next Quarter Marketing Focus
#
# #### Based on the sales analysis, the company should continue focusing marketing efforts on the Technology & Accessories category because it generated the highest total revenue in both New York and Colorado. These products appear to be the strongest drivers of sales and profitability across both territories.
#
# #### The Stationery and Supplies category also had the highest number of transactions, showing strong customer demand and frequent purchases. Promotions, bundle deals, or loyalty rewards for these products could help increase repeat customer spending.
#
# #### Books (General) had the lowest revenue and transaction totals in both territories, suggesting an opportunity for growth. The company could improve sales in this category by offering discounts, targeted advertising, seasonal promotions, or product bundles.
#
# #### Colorado generated higher overall revenue than New York in nearly every category, especially in Technology & Accessories. Because of this strong performance, additional marketing investment in Colorado may lead to even greater returns next quarter.

# %% [markdown]
# # Visualization
